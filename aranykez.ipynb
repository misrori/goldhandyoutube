# %% [markdown]
# <a href="https://colab.research.google.com/github/misrori/goldhandyoutube/blob/main/aranykez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install goldhand
# !pip install -U kaleido

# %% [markdown]
# # session restart a kaleido miatt

# %%
from goldhand import *
tw = Tw()

# %% [markdown]
# # itt szép a plot

# %%
t = GoldHand('TSLA')
t.plotly_last_year(tw.get_plotly_title('TSLA')).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # itt kiírom viszon nem lesz szép, az emojik eltűnnek

# %%
t = GoldHand('TSLA')
p = t.plotly_last_year(tw.get_plotly_title('TSLA'))
p.update_layout(height=1080, width=1920)
p.write_image("fig1.png")
